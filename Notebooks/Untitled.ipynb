# %%
import dowhy
from causalgraphicalmodels import CausalGraphicalModel
from sklearn.model_selection import train_test_split
import pandas as pd
import sys
sys.path.append("../scripts/")
from plots import plot_distribution
import warnings
warnings.filterwarnings('ignore')
from dowhy import CausalModel
from IPython.display import Image, display

# %%
df = pd.read_csv('/home/amon/Desktop/10Academy/industry-casualty/Data/final_data.csv')

# %%
df_drop = df.drop(['Unnamed: 0'], axis=1)
df_drop.head()
# Out:
#    texture_mean  radius_worst  texture_worst  concavity_worst  area_se  \
# 0         17.77         24.99          23.41           0.2416    74.08
# 1         21.25         23.57          25.53           0.4504    94.03
# 2         14.34         22.54          16.67           0.4000    94.44
# 3         15.70         15.47          23.75           0.5355    27.19
# 4         19.98         22.88          27.66           0.3784    53.91
#
#    diagnosis
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
df_drop.shape
# Out:
# (487, 6)

# %%
from causalnex.structure.notears import from_pandas
sm = from_pandas(df_drop)

# %%
from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE
viz = plot_structure(
    sm,
    graph_attributes={"scale": "0.5"},
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK)
filename = "./structure_model.png"
viz.draw(filename)
Image(filename)

# %%
sm.remove_edges_below_threshold(0.8)
viz = plot_structure(
    sm,
    graph_attributes={"scale": "0.5"},
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK)
Image(viz.draw(format='png'))
